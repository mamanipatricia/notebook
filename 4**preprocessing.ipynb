# %% [markdown]
# # PRE-PROCESSING

# %%
# importando las librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # los graficos, el odulo pyplot
import seaborn as sb   # es una sobrecapa de matplotlib, permite hacer graficos estadisticos
# %matplotlib inline

# %%
XC = pd.read_csv('./XC.csv')
XD = pd.read_csv('./XD.csv')

# %%
# XC.dtypes
# XD.dtypes

# %%
XC
# Out:
#      amoblado  bathroom  baulera  bedroom  dimension_built  dimension_ground  \
# 0           0       4.0        0      4.0              286               261
# 1           0       3.0        0      4.0              225               225
# 2           0       4.0        0      4.0              432               850
# 3           0       6.0        0      3.0              600               603
# 4           0       4.0        0      5.0              250               300
# 5           0       6.0        0      4.0              345               351
# 6           0       5.0        0      4.0              620              1050
# 7           0       5.0        0      4.0              557               930
# 8           0       6.0        0      6.0              485               500
# 9           0       5.0        0      4.0              492               320
# 10          0       4.0        0      5.0              500               650
# 11          0       4.0        0      4.0              304               494
# 12          0       2.0        0      3.0              165               165
# 13          0       5.0        0      4.0              420               627
# 14          0       4.0        0      4.0              307               185
# 15          0       4.0        0      3.0              625               717
# 16          0       5.0        0     20.0              470               571
# 17          0       3.0        0      7.0              195               250
# 18          0       2.0        0      4.0              235               497
# 19          0       2.0        0      3.0                0               350
# 20          0       4.0        0      4.0              200               300
# 21          0       4.0        0      3.0              337               300
# 22          0       3.0        0      5.0              257               200
# 23          0       3.0        0      4.0              335               448
# 24          0       4.0        0      6.0                0               204
# 25          0       6.0        0      4.0                0              1461
# 26          0       5.0        0      4.0              500               777
# 27          0       4.0        0      3.0              423                 0
# 28          0       5.0        0      5.0              433               356
# 29          0       5.0        0      4.0              435               430
# ..        ...       ...      ...      ...              ...               ...
# 572         0       3.0        0      4.0              160               250
# 573         0       6.0        0      6.0              720               890
# 574         0       6.0        0      4.0              600               600
# 575         0       4.0        0      4.0              270               350
# 576         0       4.0        0      4.0              420               630
# 577         0       5.0        0      5.0              430               300
# 578         0       2.0        0      3.0              215               645
# 579         0       5.0        0      4.0              620              1050
# 580         0       5.0        0      4.0              500               500
# 581         0       5.0        0      4.0              475               520
# 582         0       4.0        0      3.0              237               142
# 583         0       4.0        0      3.0              232               171
# 584         0       5.0        0      4.0              400               650
# 585         0       3.0        0      3.0              207               163
# 586         0       5.0        0      4.0              500               500
# 587         0       5.0        0      4.0              296               298
# 588         0       3.0        0      4.0              680               400
# 589         0       5.0        0      4.0              270               150
# 590         0       6.0        0      5.0              450               300
# 591         0       3.0        0      4.0              680               400
# 592         0       4.0        1      4.0              457               427
# 593         0       8.0        0      7.0              613               400
# 594         0       4.0        0      3.0              467               480
# 595         0       4.0        0      4.0              420               620
# 596         0       4.0        0      4.0              943                 0
# 597         0       5.0        0      4.0              362               176
# 598         0       8.0        0     12.0                0               910
# 599         0       8.0        0     12.0                0               910
# 600         0       4.0        0      4.0              943                 0
# 601         0       6.0        0      7.0              340               603
#
#      garage  id_neighborhood    latitud   longitud  neighborhood      price  \
# 589       2              180 -16.519421 -68.076736   Alto Irpavi   183000.0
# 590       2               29 -16.519045 -68.060539      Achumani   413000.0
# 591       4               32 -16.544624 -68.084351      Calacoto   780000.0
# 592       1               29 -16.522642 -68.062607      Achumani   460000.0
# 593      10               29 -16.536041 -68.075798      Achumani   800000.0
# 594       4               35 -16.542818 -68.065536     Cota Cota   470000.0
# 595       3               29 -16.516155 -68.061890      Achumani   559000.0
# 596       1               42 -16.522842 -68.108994       Obrajes   760000.0
# 597       1              151 -16.558542 -68.093262      Aranjuez   290000.0
# 598       8               32 -16.543055 -68.086182      Calacoto  1183000.0
# 599       8               32 -16.541281 -68.087914      Calacoto  1183000.0
# 600       1               42 -16.525251 -68.110901       Obrajes   760000.0
# 601       4               37 -16.527731 -68.086525        Irpavi   498000.0
#
#      status type_offer  year_built    riesgo
# 0         2      Venta         NaN      bajo
# 1         2      Venta         NaN  moderado
# 2         2      Venta         NaN  moderado
# 3         2      Venta         NaN  moderado
# 4         1      Venta      2019.0      alto
# 5         2      Venta         NaN      alto
# 6         2      Venta         NaN      bajo
# 7         2      Venta      1990.0      bajo
# 8         2      Venta         NaN  moderado
# 9         2      Venta      2008.0      alto
# 10        2      Venta         NaN      alto
# 11        2      Venta         NaN  moderado
# 12        1      Venta      2018.0      alto
# 13        2      Venta      2010.0      alto
# 14        2      Venta         NaN  moderado
# 15        2      Venta      2015.0      alto
# 16        2      Venta         NaN  moderado
# 17        2      Venta         NaN      bajo
# 18        2      Venta      1994.0      bajo
# 19        2      Venta         NaN  moderado
# 20        1      Venta      2018.0      alto
# 21        2      Venta         NaN      bajo
# 22        2      Venta         NaN  moderado
# 23        2      Venta      2005.0      alto
# 24        2      Venta         NaN      bajo
# 25        2      Venta      2000.0  moderado
# 26        1      Venta      2001.0      bajo
# 27        1      Venta      2017.0      bajo
# 28        2      Venta         NaN  muy bajo
# 29        2      Venta         NaN      alto
# ..      ...        ...         ...       ...
# 572       2      Venta         NaN      alto
# 573       2      Venta         NaN      alto
# 574       2      Venta      2004.0      alto
# 575       2      Venta         NaN      alto
# 576       2      Venta         NaN  moderado
# 577       1      Venta      2019.0      alto
# 578       2      Venta      1984.0      bajo
# 579       2      Venta         NaN      bajo
# 580       2      Venta         NaN      alto
# 581       2      Venta         NaN  moderado
# 582       1      Venta         NaN      alto
# 583       1      Venta         NaN      alto
# 584       2      Venta         NaN  moderado
# 585       1      Venta      2018.0      alto
# 586       2      Venta         NaN      alto
# 587       2      Venta      2014.0      alto
# 588       2      Venta         NaN      bajo
# 589       2      Venta         NaN      bajo
# 590       1      Venta      2015.0      alto
# 591       2      Venta         NaN      bajo
# 592       2      Venta         NaN      alto
# 593       1      Venta      2017.0      alto
# 594       2      Venta      2014.0  moderado
# 595       2      Venta         NaN      alto
# 596       2      Venta         NaN      bajo
# 597       2      Venta         NaN  moderado
# 598       2      Venta         NaN      bajo
# 599       2      Venta         NaN      bajo
# 600       2      Venta         NaN      bajo
# 601       2      Venta         NaN  moderado
#
# [602 rows x 16 columns]

# %% [markdown]
# ## One hot encoding

# %%
XC = pd.get_dummies(XC, prefix_sep="__",columns=['riesgo'])
XD = pd.get_dummies(XD, prefix_sep="__",columns=['riesgo'])

# %%
# XD = pd.get_dummies(XD, prefix_sep="__",columns=['type_offer'])
# XC = pd.get_dummies(XC, prefix_sep="__",columns=['type_offer'])

# %%
# XD.sample(2)
XC.head()
# XC.sample(2)
# Out:
#    amoblado  bathroom  baulera  bedroom  dimension_built  dimension_ground  \
# 0         0       4.0        0      4.0              286               261
# 1         0       3.0        0      4.0              225               225
# 2         0       4.0        0      4.0              432               850
# 3         0       6.0        0      3.0              600               603
# 4         0       4.0        0      5.0              250               300
#
#    garage  id_neighborhood    latitud   longitud neighborhood     price  \
# 0       2               38 -16.532234 -68.079918        Koani  250000.0
# 1       0               35 -16.538757 -68.057556    Cota Cota  250000.0
# 2       3              151 -16.559860 -68.094620     Aranjuez  530000.0
# 3       2               37 -16.514441 -68.086395       Irpavi  580000.0
# 4       3               29 -16.513678 -68.053596     Achumani  169000.0
#
#    status type_offer  year_built  riesgo__alto  riesgo__bajo  \
# 0       2      Venta         NaN             0             1
# 1       2      Venta         NaN             0             0
# 2       2      Venta         NaN             0             0
# 3       2      Venta         NaN             0             0
# 4       1      Venta      2019.0             1             0
#
#    riesgo__moderado  riesgo__muy bajo
# 0                 0                 0
# 1                 1                 0
# 2                 1                 0
# 3                 1                 0
# 4                 0                 0

# %%
# XC[XC['dimension_built'] == 0XC['dimension_ground'] == 0]
# XC[XC['dimension_ground']==0]

# %%
def getIdNeighborhoodHouses(n):
    diccNeighborhoods = {'Koani': 1, 'Cota Cota': 2, 'Aranjuez': 3, 'Irpavi': 4, 'Achumani': 5, 'Calacoto': 6, 'San Pedro': 7, 'Pampahasi': 8, 'Bolognia': 9, 'Sopocachi': 10, 'Alto Irpavi': 11, 'Alto Obrajes': 12, 'Mecapaca': 13, 'Miraflores': 14, 'Chasquipampa': 15, 'Auquisamaña': 16, 'La Florida': 17, 'Obrajes': 18, 'Seguencoma': 19, 'Los Pinos': 20, 'Mallasilla': 21, 'San Miguel': 22, 'Ovejuyo': 23, 'Bella Vista': 24, 'Tembladerani': 25, 'San Jorge': 26, 'Centro': 27, 'Villa San Antonio': 28, 'Villa Fatima': 29, 'Mallasa': 30, 'San Alberto': 31, 'El Pedregal': 32, 'Pura Pura': 33, 'El Tejar': 34}
    for key, value in diccNeighborhoods.items():
        if key.lower().strip() == n.lower().strip():
            return value
    return 0

# %%
def getIdNeighborhoodApartment(n):
    diccNeighborhoods = {'Achumani': 1, 'Alto Irpavi': 2, 'Chasquipampa': 3, 'Calacoto': 4, 'San Jorge': 5, 'Auquisamaña': 6, 'Obrajes': 7, 'Irpavi': 8, 'Los Pinos': 9, 'Cota Cota': 10, 'El Pedregal': 11, 'Bella Vista': 12, 'Sopocachi': 13, 'La Florida': 14, 'Llojeta': 15, 'Miraflores': 16, 'San Miguel': 17, 'Centro': 18, 'Mallasa': 19, 'Bolognia': 20, 'Mallasilla': 21, 'Seguencoma': 22, 'Villa Fatima': 23, 'San Pedro': 24, 'Koani': 25, 'Villa Copacabana': 26, 'Villa San Antonio': 27, 'Alto Obrajes': 28, 'El Tejar': 29}
    for key, value in diccNeighborhoods.items():
        if key.lower().strip() == n.lower().strip():
            return value
    return 0

# %%
XC['neighborhood_encoded'] = XC.apply (lambda row: getIdNeighborhoodHouses(row['neighborhood']), axis=1)
XD['neighborhood_encoded'] = XD.apply (lambda row: getIdNeighborhoodApartment(row['neighborhood']), axis=1)

# %%
# XC = XC.drop(['neighborhood','type_offer'], axis=1)
# XD = XD.drop(['neighborhood','type_offer'], axis=1)
XC = XC.drop(['id_neighborhood','neighborhood','type_offer'], axis=1)
XD = XD.drop(['id_neighborhood','neighborhood','type_offer'], axis=1)

# %%
# XD.head(2)
XC.head()
# Out:
#    amoblado  bathroom  baulera  bedroom  dimension_built  dimension_ground  \
# 0         0       4.0        0      4.0              286               261
# 1         0       3.0        0      4.0              225               225
# 2         0       4.0        0      4.0              432               850
# 3         0       6.0        0      3.0              600               603
# 4         0       4.0        0      5.0              250               300
#
#    garage    latitud   longitud     price  status  year_built  riesgo__alto  \
# 0       2 -16.532234 -68.079918  250000.0       2         NaN             0
# 1       0 -16.538757 -68.057556  250000.0       2         NaN             0
# 2       3 -16.559860 -68.094620  530000.0       2         NaN             0
# 3       2 -16.514441 -68.086395  580000.0       2         NaN             0
# 4       3 -16.513678 -68.053596  169000.0       1      2019.0             1
#
#    riesgo__bajo  riesgo__moderado  riesgo__muy bajo  neighborhood_encoded
# 0             1                 0                 0                     1
# 1             0                 1                 0                     2
# 2             0                 1                 0                     3
# 3             0                 1                 0                     4
# 4             0                 0                 0                     5

# %%
# XC = XC.drop(XC[XC.duplicated(['amoblado','bathroom','baulera','bedroom',
#                                'dimension_built','dimension_ground','garage',
#                                'id_neighborhood','latitud','longitud','price',
#                                'status','year_built'], keep="first")].index)
XC = XC.drop(XC[XC.duplicated(['amoblado','bathroom','baulera','bedroom',
                               'dimension_built','dimension_ground','garage',
                               'neighborhood_encoded','latitud','longitud','price',
                               'status','year_built'], keep="first")].index)

# %%
# XD = XD.drop(XD[XD.duplicated(['amoblado','bathroom','baulera','bedroom',
#                                'dimension_built','dimension_ground','garage',
#                                'id_neighborhood','latitud','longitud','price',
#                                'status','year_built'], keep="first")].index)
XD = XD.drop(XD[XD.duplicated(['amoblado','bathroom','baulera','bedroom',
                               'dimension_built','dimension_ground','garage',
                               'neighborhood_encoded','latitud','longitud','price',
                               'status','year_built'], keep="first")].index)

# %%
XC.to_csv('./pre/XC.csv', index=False)

# %%
XD.to_csv('./pre/XD.csv', index=False)
